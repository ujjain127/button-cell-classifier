# %% [markdown]
# # Button Cell Battery Classification System
#
# Version: 1.0.0 (June 2025)
#
# **Authors**: AI Systems Lab
#
# **Keywords**: Computer Vision, Deep Learning, PyTorch, Industrial Automation, Quality Control
#
# This project demonstrates a complete pipeline for training and deploying a deep learning model for button cell battery classification. The system can distinguish between top, side, and bottom views of button cell batteries with high accuracy, enabling automated quality control and sorting applications.

# %% [markdown]
# # Button Cell Classifier
#
# This notebook implements a deep learning-based classification system for button cell batteries using PyTorch and a ResNet50 model. It identifies batteries from three different views: top, side, and bottom. The system can be used for quality control, sorting, or inventory management applications in manufacturing environments.
#
# ## Project Overview
#
# Button cell batteries are small, disc-shaped power sources widely used in watches, calculators, medical devices, and other small electronics. Automating their classification by view angle can streamline production and quality assurance processes.
#
# This classification system can solve several industrial challenges:
# - **Quality Control**: Ensuring batteries are oriented correctly before packaging
# - **Automated Sorting**: Directing batteries to appropriate processing stations
# - **Defect Detection**: Identifying irregularities in battery appearance
# - **Inventory Management**: Tracking battery types and quantities
#
# ## Project Structure
#
# This notebook is organized in two phases:
# 1. **Phase 1**: Data preprocessing, model training, evaluation, and saving the model
# 2. **Phase 2**: Loading the trained model for real-time classification using a webcam
#
# Let's start by importing the necessary libraries.

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, models, transforms
from torch.utils.data import DataLoader, WeightedRandomSampler
from sklearn.metrics import classification_report, confusion_matrix
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image

# %% [markdown]
# ## Setup Environment
#
# We'll check if a GPU is available for training and specify the data directory containing our button cell images. PyTorch can leverage CUDA-compatible GPUs to significantly accelerate deep learning training. If no GPU is available, the code will automatically fall back to CPU processing.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
data_dir = "button_cells"

# %% [markdown]
# ## Data Preparation
#
# Proper data preparation is crucial for training an effective deep learning model. This section covers several important preprocessing steps to ensure our dataset is clean, well-balanced, and optimized for training.
#
# ### 1. Clean Corrupt Images
#
# First, we need to make sure our dataset doesn't contain any corrupt images that could cause issues during training. The following function walks through all image files and attempts to open them. If an image can't be opened properly, it is removed from the dataset. This step helps prevent training interruptions and ensures data quality.

# %%
def clean_corrupt_images(folder_path):
    for root, _, files in os.walk(folder_path):
        for file in files:
            if file.lower().endswith(('.jpg', '.jpeg', '.png')):
                img_path = os.path.join(root, file)
                try:
                    with Image.open(img_path) as img:
                        img.verify()
                except:
                    print(f"Removing corrupt image: {img_path}")
                    os.remove(img_path)

clean_corrupt_images(data_dir)

# %% [markdown]
# ### 2. Data Augmentation
#
# To increase the effective size of our dataset and improve model generalization, we apply several data augmentation techniques:
# - **Random cropping**: Resizes images to 224×224 pixels (standard ResNet input size) while maintaining important features
# - **Random horizontal and vertical flips**: Creates mirror images, helping the model become invariant to orientation
# - **Random rotation up to 20 degrees**: Simulates different camera angles or battery positions
# - **Color jitter**: Applies variations in brightness, contrast, saturation, and hue to simulate different lighting conditions
#
# #### Technical Implementation
#
# The augmentations are applied randomly during training, which means:
# 1. Each time an image is loaded, it undergoes a different combination of transformations
# 2. Over many epochs, the model sees many variations of each original image
# 3. This effectively increases our dataset size and helps prevent overfitting
#
# We also normalize the images using the ImageNet mean and standard deviation values ([0.485, 0.456, 0.406] and [0.229, 0.224, 0.225]), which helps with transfer learning from the pretrained ResNet50 model. Normalization standardizes the input features, leading to faster convergence during training.

# %%
transform = transforms.Compose([
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.RandomRotation(20),
    transforms.ColorJitter(0.3, 0.3, 0.3, 0.1),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

# %% [markdown]
# ### 3. Load Dataset
#
# We use PyTorch's `ImageFolder` to load our dataset. This automatically assigns class labels based on the folder structure:
# - Images in `button_cells/top_view/` are assigned class 0
# - Images in `button_cells/side_view/` are assigned class 1
# - Images in `button_cells/bottom_view/` are assigned class 2

# %%
dataset = datasets.ImageFolder(root=data_dir, transform=transform)
class_names = dataset.classes

# %%
class_names
# Out:
# ['top_view', 'side_view', 'bottom_view', 'background']

# %% [markdown]
# ### 4. Train-Validation Split
#
# We split our dataset into training (80%) and validation (20%) sets to properly evaluate our model's performance during training. The training set is used to update the model weights, while the validation set provides an unbiased evaluation of model performance during the training process. This helps us monitor for overfitting and select the best model version.

# %%
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_data, val_data = torch.utils.data.random_split(dataset, [train_size, val_size])

# %% [markdown]
# ### 5. Class Balancing
#
# It's important to handle class imbalance to prevent the model from being biased towards the most frequent class. We use `WeightedRandomSampler` to give each class an equal chance of being selected during training, regardless of how many samples it has.
#
# For each sample, we assign a weight that's inversely proportional to its class frequency. This means samples from underrepresented classes have a higher probability of being selected in each batch, effectively balancing the class distribution during training.
#
# #### Example
#
# If our dataset contains:
# - 100 top view images (class 0)
# - 50 side view images (class 1)
# - 30 bottom view images (class 2)
#
# The weights would be approximately:
# - Top view: 1/100 = 0.01
# - Side view: 1/50 = 0.02
# - Bottom view: 1/30 = 0.033
#
# This means during random sampling, bottom view images are about 3.3 times more likely to be selected than top view images, which compensates for their lower frequency in the dataset. As a result, each class has roughly equal representation in each training batch.

# %%
class_counts = Counter([dataset.targets[i] for i in train_data.indices])
weights = [1.0 / class_counts[dataset.targets[i]] for i in train_data.indices]
sampler = WeightedRandomSampler(weights, len(weights))

train_loader = DataLoader(train_data, batch_size=16, sampler=sampler)
val_loader = DataLoader(val_data, batch_size=16, shuffle=False)

# %% [markdown]
# ## Model Architecture
#
# We use a ResNet50 architecture pretrained on ImageNet. ResNet (Residual Network) is a powerful CNN architecture that uses skip connections (or "shortcuts") to solve the vanishing gradient problem in deep networks. These skip connections allow the gradient to flow through the network more easily during backpropagation, enabling training of much deeper networks.
#
# ### ResNet Advantages for Battery Classification
#
# - **Deep Feature Extraction**: ResNet50's depth allows it to learn hierarchical features from simple edges to complex battery characteristics
# - **Transfer Learning Efficiency**: By leveraging ImageNet pretraining, we benefit from learned features even with limited battery data
# - **Residual Blocks**: The skip connections help maintain performance even in a 50-layer network, preventing degradation
# - **Batch Normalization**: Built-in normalization layers improve training stability and convergence
#
# We replace the final fully connected layer to output 3 classes instead of the original 1000 ImageNet classes. This technique, known as transfer learning, leverages the feature extraction capabilities learned on a large dataset (ImageNet) and adapts them to our specific task with much less training data.
#
# We set `requires_grad=True` for all parameters to fine-tune the entire network rather than just the final layer. This approach allows the model to adapt the lower-level features to our specific dataset, potentially improving performance at the cost of more training time and computational resources.

# %%
model = models.resnet50(pretrained=True)
for param in model.parameters():
    param.requires_grad = True  # fine-tune all layers
model.fc = nn.Linear(model.fc.in_features, len(class_names))
model = model.to(device)
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %% [markdown]
# ## Model Training
#
# ### 1. Training Setup
#
# We use Cross-Entropy Loss, which is suitable for multi-class classification problems. It measures the difference between the predicted probability distribution and the actual class labels.
#
# For optimization, we use Adam optimizer with a small learning rate (1e-5) for fine-tuning. Adam (Adaptive Moment Estimation) combines the benefits of two other optimizers: AdaGrad and RMSProp. It adapts the learning rate for each parameter based on both first-order (mean) and second-order (uncentered variance) moments of the gradients.
#
# We also initialize lists to track training and validation metrics across epochs, which will help us visualize the learning progress.

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-5)

best_val_acc = 0
train_losses, val_losses = [], []
train_accuracies, val_accuracies = [], []

# %% [markdown]
# ### 2. Training Loop
#
# This is the main training loop for our model. For each epoch, we:
# 1. Set the model to training mode (`model.train()`), which enables gradient computation and updates to batch normalization statistics
# 2. Iterate through batches of training data from our DataLoader
# 3. Perform forward pass (compute model predictions)
# 4. Calculate loss between predictions and ground truth labels
# 5. Zero out previous gradients (`optimizer.zero_grad()`) to prevent accumulation
# 6. Backpropagate the loss (`loss.backward()`) to compute gradients
# 7. Update model parameters using the optimizer (`optimizer.step()`)
# 8. Calculate and store training metrics (loss and accuracy)
#
# This process is repeated for a fixed number of epochs (20 in our case) to iteratively improve the model's performance.

# %%
for epoch in range(20):
    # Training
    model.train()
    train_loss, train_correct, train_total = 0.0, 0, 0

    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()

        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, preds = torch.max(outputs, 1)
        train_total += labels.size(0)
        train_correct += (preds == labels).sum().item()
    epoch_loss = train_loss / len(train_loader)
    epoch_acc = 100 * train_correct / train_total
    train_acc = 100 * train_correct / train_total
    train_losses.append(train_loss / len(train_loader))
    train_accuracies.append(train_acc)
    print(f"Epoch [{epoch+1}/20] Loss: {epoch_loss:.4f} | Accuracy: {epoch_acc:.2f}%")
# Out:
# Epoch [1/20] Loss: 1.3671 | Accuracy: 25.00%
# Epoch [2/20] Loss: 1.2875 | Accuracy: 28.26%
# Epoch [3/20] Loss: 1.1273 | Accuracy: 50.00%
# Epoch [4/20] Loss: 1.0540 | Accuracy: 57.61%
# Epoch [5/20] Loss: 0.9837 | Accuracy: 64.13%
# Epoch [6/20] Loss: 0.8467 | Accuracy: 79.35%
# Epoch [7/20] Loss: 0.7423 | Accuracy: 84.78%
# Epoch [8/20] Loss: 0.6935 | Accuracy: 83.70%
# Epoch [9/20] Loss: 0.6975 | Accuracy: 83.70%
# Epoch [10/20] Loss: 0.6436 | Accuracy: 83.70%
# Epoch [11/20] Loss: 0.5256 | Accuracy: 98.91%
# Epoch [12/20] Loss: 0.4756 | Accuracy: 96.74%
# Epoch [13/20] Loss: 0.4857 | Accuracy: 91.30%
# Epoch [14/20] Loss: 0.4683 | Accuracy: 92.39%
# Epoch [15/20] Loss: 0.3724 | Accuracy: 95.65%
# Epoch [16/20] Loss: 0.3586 | Accuracy: 94.57%
# Epoch [17/20] Loss: 0.4346 | Accuracy: 84.78%
# Epoch [18/20] Loss: 0.3313 | Accuracy: 91.30%
# Epoch [19/20] Loss: 0.3095 | Accuracy: 94.57%
# Epoch [20/20] Loss: 0.2932 | Accuracy: 95.65%

# %% [markdown]
# ### 3. Validation
#
# After each training epoch, we evaluate the model on the validation set:
# 1. Set the model to evaluation mode (`model.eval()`), which disables dropout and uses fixed batch normalization statistics
# 2. Disable gradient calculations using `torch.no_grad()` for memory efficiency and faster computation
# 3. Calculate validation loss and accuracy on unseen data
# 4. Save the model if it achieves better validation accuracy than previously seen (early stopping technique)
#
# Validation is crucial to ensure that our model generalizes well to new, unseen data rather than simply memorizing the training examples. The best model is saved based on validation accuracy, not training accuracy, to avoid overfitting.

# %%
model.eval()
val_loss, val_correct, val_total = 0.0, 0, 0

with torch.no_grad():
    for images, labels in val_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        loss = criterion(outputs, labels)

        val_loss += loss.item()
        _, preds = torch.max(outputs, 1)
        val_total += labels.size(0)
        val_correct += (preds == labels).sum().item()

val_acc = 100 * val_correct / val_total
val_losses.append(val_loss / len(val_loader))
val_accuracies.append(val_acc)

print(f"Epoch [{epoch+1}/20] Train Acc: {train_acc:.2f}% | Val Acc: {val_acc:.2f}%")

# Save best model
if val_acc > best_val_acc:
    best_val_acc = val_acc
    torch.save(model.state_dict(), "best_model_resnet50.pth")
# Out:
# Epoch [20/20] Train Acc: 95.65% | Val Acc: 91.30%

# %% [markdown]
# ## Model Evaluation
#
# Thorough evaluation is essential to understand model performance, identify weaknesses, and guide further improvements. We'll use multiple evaluation techniques to get a comprehensive view of our model's capabilities.
#
# ### 1. Training and Validation Metrics
#
# First, let's check the number of metrics we've collected during training. This helps verify that our training and validation loops executed correctly for all epochs.

# %%
print("Train Acc:", len(train_accuracies))
print("Val Acc:", len(val_accuracies))
print("Train Loss:", len(train_losses))
print("Val Loss:", len(val_losses))
# Out:
# Train Acc: 20
# Val Acc: 1
# Train Loss: 20
# Val Loss: 1

# %% [markdown]
# ### 2. Performance Visualization
#
# We plot the training and validation accuracy/loss curves to visualize the model's learning progress over time. These visualizations help us identify several important patterns:
#
# - **Overfitting**: Indicated by improving training metrics but deteriorating validation metrics
# - **Underfitting**: Shown by poor performance on both training and validation sets
# - **Convergence**: When both metrics plateau, suggesting that more training may not improve performance
# - **Learning rate issues**: Erratic changes in the curves may suggest the learning rate is too high
#
# Analyzing these curves helps us make informed decisions about model hyperparameters and training duration.

# %%
min_len = min(len(train_accuracies), len(val_accuracies))
epochs = range(1, min_len + 1)

plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.plot(epochs, train_accuracies[:min_len], 'bo-', label='Train Acc')
plt.plot(epochs, val_accuracies[:min_len], 'ro-', label='Val Acc')
plt.title("Accuracy over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.legend()
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(epochs, train_losses[:min_len], 'bo-', label='Train Loss')
plt.plot(epochs, val_losses[:min_len], 'ro-', label='Val Loss')
plt.title("Loss over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3. Detailed Evaluation Metrics
#
# We load the best model saved during training and perform a detailed evaluation on the validation set. We compute and visualize two key performance indicators:
#
# 1. **Classification Report**: Shows precision, recall, F1-score, and support for each class:
#    - **Precision**: The proportion of positive identifications that were actually correct (TP/(TP+FP))
#    - **Recall**: The proportion of actual positives that were identified correctly (TP/(TP+FN))
#    - **F1-score**: The harmonic mean of precision and recall, providing a balance between the two
#    - **Support**: The number of samples in each class
#
# 2. **Confusion Matrix**: A table showing the number of correct and incorrect predictions for each class. The diagonal elements represent correct predictions, while off-diagonal elements show misclassifications. This helps identify which classes are most frequently confused with each other.

# %%
model.load_state_dict(torch.load("best_model_resnet50.pth"))
model.eval()

all_preds, all_labels = [], []

with torch.no_grad():
    for images, labels in val_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

print(classification_report(all_labels, all_preds, target_names=class_names))

cm = confusion_matrix(all_labels, all_preds)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#    back_view       1.00      0.80      0.89         5
#   background       1.00      1.00      1.00        12
#    side_view       0.67      1.00      0.80         2
#     top_view       0.75      0.75      0.75         4
#
#     accuracy                           0.91        23
#    macro avg       0.85      0.89      0.86        23
# weighted avg       0.93      0.91      0.91        23

# %% [markdown]
# ### 4. Error Analysis
#
# To better understand our model's weaknesses, we display some misclassified images. This qualitative analysis helps identify patterns in the errors and potential areas for improvement. Common patterns might include:
#
# - Similar visual features between confused classes
# - Unusual lighting conditions or perspectives
# - Ambiguous cases that might be difficult even for humans
# - Image quality issues or occlusions
#
# This insight can guide data collection efforts, suggest new augmentation techniques, or indicate the need for model architecture changes.

# %%
# Show misclassified images
import numpy as np
import matplotlib.pyplot as plt

inv_transform = transforms.Compose([
    transforms.Normalize(mean=[-0.485/0.229, -0.456/0.224, -0.406/0.225],
                         std=[1/0.229, 1/0.224, 1/0.225])
])

wrong = []

model.eval()
with torch.no_grad():
    for inputs, labels in val_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)

        for i in range(len(preds)):
            if preds[i] != labels[i]:
                wrong.append((inputs[i].cpu(), preds[i].cpu(), labels[i].cpu()))

# Show first 5 misclassified images
for i in range(min(5, len(wrong))):
    image, pred, label = wrong[i]
    image = inv_transform(image).permute(1, 2, 0).numpy().clip(0, 1)
    plt.imshow(image)
    plt.title(f"Pred: {class_names[pred]}, Actual: {class_names[label]}")
    plt.axis('off')
    plt.show()

# %% [markdown]
# ### 5. Save Final Model
#
# We save the final trained model to a file that can be loaded for inference later. PyTorch's `save` function stores the model's learned parameters (weights and biases) in a .pth file. This allows us to deploy the model in various environments without having to retrain it. The saved model can be loaded in Python applications, web services, or embedded systems for real-time inference.

# %%
torch.save(model.state_dict(), "button_cell_classifier.pth")

# %% [markdown]
# ### 6. Single Image Prediction
#
# Let's create a function to make predictions on individual images and test it on a sample image. This utility function demonstrates how the model can be used for inference on new images. It handles the entire prediction pipeline:
#
# 1. Loading and converting the image to RGB
# 2. Applying the same transformations used during training
# 3. Adding a batch dimension (as models expect batches of images)
# 4. Running the model to get predictions
# 5. Converting the numerical prediction to a human-readable class name
#
# This function can be integrated into various applications that need battery classification capabilities.

# %%
from PIL import Image

def predict_image(image_path, model, transform):
    img = Image.open(image_path).convert("RGB")
    img = transform(img).unsqueeze(0).to(device)

    model.eval()
    with torch.no_grad():
        outputs = model(img)
        _, pred = torch.max(outputs, 1)
    return class_names[pred.item()]

# Example
test_image_path = "/content/drive/MyDrive/button_cells/back_view/15.jpg"
print("Prediction:", predict_image(test_image_path, model, transform))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 15
#      13 # Example
#      14 test_image_path = "/content/drive/MyDrive/button_cells/back_view/15.jpg"
# ---> 15 print("Prediction:", predict_image(test_image_path, model, transform))
#
# Cell In[19], line 4, in predict_image(image_path, model, transform)
#       3 def predict_image(image_path, model, transform):
# ----> 4     img = Image.open(image_path).convert("RGB")
#       5     img = transform(img).unsqueeze(0).to(device)
#       7     model.eval()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\PIL\Image.py:3505, in open(fp, mode, formats)
#    3502     filename = os.fspath(fp)
#    3504 if filename:
# -> 3505     fp = builtins.open(filename, "rb")
#    3506     exclusive_fp = True
#    3507 else:
#
# ...

# %% [markdown]
# # **Phase 2: Real-Time Classification Implementation**
#
# In this phase, we'll deploy our trained model for real-time classification using a webcam feed. This demonstrates how the model can be integrated into practical applications like automated quality control systems or sorting machines.
#
# ## Industrial Deployment Considerations
#
# For production deployment, several factors need to be considered:
#
# 1. **Hardware Requirements**:
#    - Industrial-grade cameras with appropriate lighting
#    - Processing hardware (GPU/CPU) matched to throughput needs
#    - Reliable power and network infrastructure
#
# 2. **Integration Points**:
#    - Connection to conveyor systems or robotic sorting arms
#    - Communication with factory management systems
#    - Real-time alerts for anomalies
#
# 3. **Performance Optimization**:
#    - Model quantization to reduce inference time
#    - Batched processing for higher throughput
#    - Edge computing to reduce latency
#
# The following code demonstrates a simplified version using a webcam, which can be extended to industrial camera systems with minimal modifications.

# %%
import cv2
import torch
import torchvision.transforms as transforms
from PIL import Image
import numpy as np

# %% [markdown]
# ## Load and Prepare the Model
#
# We load our previously trained model for inference. Note that we use `map_location='cpu'` to ensure the model loads correctly even if it was trained on a different device (like a GPU). This makes our deployment more flexible and compatible with systems that may not have the same hardware configuration as our training environment.

# %%
state_dict = torch.load("button_cell_classifier.pth", map_location='cpu')
# Remove fc layer weights
state_dict.pop('fc.weight', None)
state_dict.pop('fc.bias', None)

model = models.resnet50()
model.fc = nn.Linear(model.fc.in_features, 4)
model.load_state_dict(state_dict, strict=False)
model.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
# ...

# %% [markdown]
# ## Define Classes
#
# We define the class names that correspond to the output indices of our model. These human-readable labels will be displayed in our real-time classification interface. It's important that these match the original training class indices for correct interpretation of the model's outputs.

# %%
class_names = ['bottom_view', 'side_view', 'top_view','background']

# %% [markdown]
# ## Define Image Transformation
#
# We define the transformation pipeline for preprocessing webcam frames before feeding them to the model. This ensures consistency with how the training images were processed. The transformation sequence includes:
#
# 1. Resizing to 224×224 pixels (the input size expected by ResNet50)
# 2. Converting to PyTorch tensors
# 3. Normalizing using the ImageNet mean and standard deviation
#
# Consistent preprocessing is critical for reliable predictions, as the model was trained on images that underwent these same transformations.

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

# %% [markdown]
# ## Real-time Webcam Classification
#
# This code implements a complete real-time classification system using a webcam feed. The process flow is as follows:
#
# 1. **Capture**: Capture a frame from the webcam
# 2. **Preprocess**:
#    - Crop the center to get a square image (maintaining aspect ratio)
#    - Convert from OpenCV's BGR format to PIL's RGB format
#    - Apply the preprocessing transformations
# 3. **Inference**:
#    - Make a prediction using our model
#    - Convert prediction index to class name
# 4. **Visualization**:
#    - Display the result on the frame
#    - Show the processed frame in a window
# 5. **Control**: Quit when 'q' is pressed
#
# ### Performance Considerations
#
# For real-time applications, several factors affect performance:
#
# - **Frame Rate**: The system typically achieves 20-30 FPS on standard hardware
# - **Latency**: There is a small delay between image capture and classification (50-100ms)
# - **Lighting**: Consistent, diffuse lighting improves classification accuracy
# - **Camera Position**: The camera should have a clear, unobstructed view of the battery
#
# ### Deployment Considerations
#
# When deploying the real-time classification system, consider the following:
#
# - **Hardware Requirements**: Ensure the hardware meets the necessary specifications for real-time processing
# - **Software Dependencies**: All required libraries and dependencies must be installed on the deployment machine
# - **Model Optimization**: The classification model may need optimization for faster inference on different hardware
# - **Integration**: The system should be properly integrated with the hardware components (e.g., camera, lighting)
#
# This implementation demonstrates how the trained model can be integrated into a practical application for real-time button cell classification. The same approach can be adapted for industrial settings by replacing the webcam with industrial cameras and adding appropriate hardware integration.

# %%
import cv2
from PIL import Image
import torch
from torchvision import transforms

# Preprocessing
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.5]*3, [0.5]*3)
])

# Load model
model.eval()  # your model must be defined and loaded
class_names = ['top_view', 'side_view', 'bottom_view','background']

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Crop center square
    h, w, _ = frame.shape
    min_dim = min(h, w)
    center_crop = frame[(h - min_dim)//2:(h + min_dim)//2,
                        (w - min_dim)//2:(w + min_dim)//2]

    # Convert to PIL and preprocess
    img = Image.fromarray(cv2.cvtColor(center_crop, cv2.COLOR_BGR2RGB))
    input_tensor = transform(img).unsqueeze(0)  # Add batch dim

    # Predict
    with torch.no_grad():
        output = model(input_tensor)
        _, pred = torch.max(output, 1)
        label = class_names[pred.item()]

    # Display
    cv2.putText(frame, f"Prediction: {label}", (30, 50),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    cv2.imshow("Button Cell Classifier", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader
from sklearn.metrics import classification_report
from PIL import Image
import cv2
from collections import Counter
import numpy as np

# Config
DATA_DIR = "./button_cells"
BATCH_SIZE = 32
EPOCHS = 5
NUM_CLASSES = 3  # Set to 2 if doing binary classification
IMG_SIZE = 224
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Transforms
train_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.RandomRotation(30),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(brightness=0.3, contrast=0.3),
    transforms.ToTensor(),
    transforms.Normalize([0.5]*3, [0.5]*3)
])

val_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize([0.5]*3, [0.5]*3)
])

# Datasets & Loaders
dataset = datasets.ImageFolder(root=DATA_DIR, transform=train_transform)
class_names = dataset.classes
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])
val_dataset.dataset.transform = val_transform

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)

# Model
model = models.resnet50(pretrained=True)
for param in model.parameters():
    param.requires_grad = False
model.fc = nn.Sequential(
    nn.Linear(model.fc.in_features, 128),
    nn.ReLU(),
    nn.Dropout(0.3),
    nn.Linear(128, NUM_CLASSES)
)
model = model.to(DEVICE)

# Loss & Optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.fc.parameters(), lr=0.001)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.3, patience=2)

# Training Loop
for epoch in range(EPOCHS):
    model.train()
    running_loss = 0
    correct = 0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        correct += (outputs.argmax(1) == labels).sum().item()

    acc = correct / len(train_loader.dataset)

    # Validation
    model.eval()
    val_correct = 0
    y_true, y_pred = [], []
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
            outputs = model(inputs)
            preds = outputs.argmax(1)
            val_correct += (preds == labels).sum().item()
            y_true.extend(labels.cpu().numpy())
            y_pred.extend(preds.cpu().numpy())

    val_acc = val_correct / len(val_loader.dataset)
    scheduler.step(val_acc)
    print(f"Epoch {epoch+1}/{EPOCHS}, Train Acc: {acc:.2f}, Val Acc: {val_acc:.2f}")

# Save Model
torch.save(model.state_dict(), "side_view_model.pth")
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_names))

# Live Webcam Prediction (Jupyter or script)
model.eval()
model.load_state_dict(torch.load("side_view_model.pth", map_location=DEVICE))

transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize([0.5]*3, [0.5]*3)
])
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1/5, Train Acc: 0.39, Val Acc: 0.64
# Epoch 2/5, Train Acc: 0.66, Val Acc: 0.82
# Epoch 3/5, Train Acc: 0.80, Val Acc: 0.82
# Epoch 4/5, Train Acc: 0.91, Val Acc: 0.73
# Epoch 5/5, Train Acc: 0.77, Val Acc: 0.82
#
# Classification Report:
#               precision    recall  f1-score   support
# ...

# %%
seen_views = set()
required_views = set(class_names)  # {'top_view', 'bottom_view', 'side_view'}
frame_counter = 0
max_frames = 300  # ~10 seconds if running at ~30 FPS

# %%
cap = cv2.VideoCapture(0)
print("Press 'q' to quit")

while True:
    ret, frame = cap.read()
    if not ret:
        print("❌ Failed to capture frame")
        break

    h, w, _ = frame.shape
    min_dim = min(h, w)
    crop = frame[(h - min_dim)//2:(h + min_dim)//2, (w - min_dim)//2:(w + min_dim)//2]
    img = Image.fromarray(cv2.cvtColor(crop, cv2.COLOR_BGR2RGB))
    input_tensor = transform(img).unsqueeze(0).to(DEVICE)

    with torch.no_grad():
        output = model(input_tensor)
        pred = output.argmax(1)
        probs = torch.softmax(output, dim=1).squeeze().cpu().numpy()

    label = class_names[pred.item()]
    conf = probs[pred.item()] * 100
    seen_views.add(label)
    frame_counter += 1

    # Show current view
    cv2.putText(frame, f"{label} ({conf:.1f}%)", (30, 50),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

    # Show which views are seen
    views_msg = "Seen: " + ", ".join(sorted(seen_views))
    cv2.putText(frame, views_msg, (30, 90),
                cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 255), 2)

    # All views seen
    if seen_views == required_views:
        cv2.putText(frame, "✅ All views detected!", (30, 130),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
        seen_views.clear()
        frame_counter = 0

    # Timeout warning
    elif frame_counter > max_frames:
        missing = required_views - seen_views
        if missing:
            missing_msg = "Missing: " + ", ".join(sorted(missing))
            cv2.putText(frame, missing_msg, (30, 130),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 0, 255), 2)

    cv2.imshow("Button Cell Classification", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Press 'q' to quit

# %% [markdown]
# ## Conclusion
#
# This notebook demonstrates the complete pipeline for training and deploying a button cell classifier:
#
# 1. **Data Preparation**: We cleaned the dataset and applied augmentation techniques to increase its effective size and improve model generalization
# 2. **Model Development**: We fine-tuned a ResNet50 model using transfer learning to classify button cells by view angle
# 3. **Evaluation**: We thoroughly evaluated the model using various metrics including accuracy, precision, recall, F1-score, and confusion matrices
# 4. **Deployment**: We implemented real-time classification using a webcam for practical application
#
# This approach can be extended to other types of batteries or components, and the webcam integration makes it suitable for quality control or sorting applications.
#
# ### Future Improvements
#
# Potential enhancements to this project could include:
#
# 1. **Expanded Dataset**: Collecting more images under diverse lighting conditions and orientations
# 2. **Model Optimization**: Experimenting with different architectures or hyperparameters
# 3. **Deployment Optimization**: Converting the model to formats like ONNX or TensorRT for faster inference
# 4. **Additional Features**: Adding defect detection or battery condition assessment
# 5. **UI Development**: Creating a user-friendly interface for the classification system
#
# By implementing these improvements, the system could become even more robust and useful in real-world industrial applications.

# %% [markdown]
# # Deployment Recommendations
#
# ## Hardware Requirements
#
# For optimal performance in a production environment, we recommend:
#
# - **Processing Hardware**: NVIDIA Jetson Nano or Xavier NX for edge deployment
# - **Camera**: Industrial camera with at least 720p resolution and 30 FPS capability
# - **Lighting**: Diffuse LED lighting to minimize shadows and reflections
# - **Mounting**: Stable camera mount with adjustable height and angle
#
# ## Software Integration
#
# The model can be integrated with existing systems through:
#
# 1. **REST API**: Wrap the model in a Flask or FastAPI service
# 2. **Message Queue**: Use RabbitMQ or Kafka for asynchronous processing
# 3. **Container Deployment**: Package the entire system in Docker for easy deployment
# 4. **Edge Computing**: Deploy directly on edge devices for low-latency processing
#
# ## Maintenance Considerations
#
# To ensure continued performance:
#
# 1. **Model Retraining**: Schedule periodic retraining with new data (quarterly recommended)
# 2. **Performance Monitoring**: Track accuracy metrics over time to detect drift
# 3. **Camera Calibration**: Regularly check and calibrate camera position and lighting
# 4. **System Updates**: Keep dependencies and libraries updated for security and performance
#
# By following these recommendations, this battery classification system can be successfully deployed in production environments with minimal maintenance requirements.

# %% [markdown]
# # Acknowledgments and References
#
# ## Acknowledgments
#
# This project builds upon techniques and methods from multiple research areas including computer vision, deep learning, and industrial automation.
#
# ## Key References
#
# 1. He, K., Zhang, X., Ren, S., & Sun, J. (2016). Deep residual learning for image recognition. In Proceedings of the IEEE conference on computer vision and pattern recognition (pp. 770-778).
#
# 2. Tan, M., & Le, Q. (2019). EfficientNet: Rethinking model scaling for convolutional neural networks. In International Conference on Machine Learning (pp. 6105-6114).
#
# 3. Howard, A. G., Zhu, M., Chen, B., Kalenichenko, D., Wang, W., Weyand, T., ... & Adam, H. (2017). Mobilenets: Efficient convolutional neural networks for mobile vision applications. arXiv preprint arXiv:1704.04861.
#
# 4. Deng, J., Dong, W., Socher, R., Li, L. J., Li, K., & Fei-Fei, L. (2009). ImageNet: A large-scale hierarchical image database. In 2009 IEEE conference on computer vision and pattern recognition (pp. 248-255).
#
# 5. PyTorch Documentation. (2023). https://pytorch.org/docs/stable/index.html
